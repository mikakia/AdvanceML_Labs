# %% [markdown]
# <a href="https://colab.research.google.com/github/mikakia/AdvanceML_Labs/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
